# %%
import pandas as pd

# Load dataset from Johns Hopkins University Github page
# with command pd.read_csv("datafile.csv")
covid_daily_report = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-24-2021.csv")

# %%
covid_daily_report
# Out:
#       FIPS Admin2 Province_State      Country_Region          Last_Update  \
# 0      NaN    NaN            NaN         Afghanistan  2021-04-25 04:20:32
# 1      NaN    NaN            NaN             Albania  2021-04-25 04:20:32
# 2      NaN    NaN            NaN             Algeria  2021-04-25 04:20:32
# 3      NaN    NaN            NaN             Andorra  2021-04-25 04:20:32
# 4      NaN    NaN            NaN              Angola  2021-04-25 04:20:32
# ...    ...    ...            ...                 ...                  ...
# 3978   NaN    NaN            NaN             Vietnam  2021-04-25 04:20:32
# 3979   NaN    NaN            NaN  West Bank and Gaza  2021-04-25 04:20:32
# 3980   NaN    NaN            NaN               Yemen  2021-04-25 04:20:32
# 3981   NaN    NaN            NaN              Zambia  2021-04-25 04:20:32
# 3982   NaN    NaN            NaN            Zimbabwe  2021-04-25 04:20:32
#
#             Lat       Long_  Confirmed  Deaths  Recovered   Active  \
# ...
